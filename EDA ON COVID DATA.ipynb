# %%
import pandas as pd

# %% [markdown]
# # 1 Import the dataset using Pandas from mentioned url.

# %%
df=pd.read_csv("https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv") 
df
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# # 2. High Level Data Understanding:

# %%
#a. Find no. of rows & columns in the dataset
df.shape
# Out:
# (57394, 49)

# %%
#b. Data types of columns.
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
#c.Info & describe of data in dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
df.describe(include="all")
# Out:
#        iso_code continent     location      date   total_cases      new_cases  \
# count     57071     56748        57394     57394  5.375800e+04   56465.000000
# unique      215         6          216       323           NaN            NaN
# top         AFG    Europe  Afghanistan  30/10/20           NaN            NaN
# freq        323     14828          323       215           NaN            NaN
# mean        NaN       NaN          NaN       NaN  1.677974e+05    1953.576941
# std         NaN       NaN          NaN       NaN  1.693038e+06   18269.650340
# min         NaN       NaN          NaN       NaN  1.000000e+00   -8261.000000
# 25%         NaN       NaN          NaN       NaN  1.800000e+02       0.000000
# 50%         NaN       NaN          NaN       NaN  2.070000e+03      14.000000
# 75%         NaN       NaN          NaN       NaN  2.235675e+04     235.000000
# max         NaN       NaN          NaN       NaN  5.515465e+07  646281.000000
#
# ...

# %% [markdown]
# # 3.Low Level Data Understanding :

# %%
#a.Find count of unique values in location column.
df["iso_code"].nunique()
# Out:
# 215

# %%
#b. Find which continent has maximum frequency using valuescounts.
freq = df.value_counts()
freq
# Out:
# Series([], dtype: int64)

# %%
#c. Find maximum & mean value in 'total_cases'.
df["total_cases"].max()
# Out:
# 55154651.0

# %%
df["total_cases"].mean()
# Out:
# 167797.3688753302

# %%
#d. Find 25%,50% & 75% quartile value in 'total_deaths'
df.describe(include="all")
# Out:
#        iso_code continent     location      date   total_cases      new_cases  \
# count     57071     56748        57394     57394  5.375800e+04   56465.000000
# unique      215         6          216       323           NaN            NaN
# top         AFG    Europe  Afghanistan  30/10/20           NaN            NaN
# freq        323     14828          323       215           NaN            NaN
# mean        NaN       NaN          NaN       NaN  1.677974e+05    1953.576941
# std         NaN       NaN          NaN       NaN  1.693038e+06   18269.650340
# min         NaN       NaN          NaN       NaN  1.000000e+00   -8261.000000
# 25%         NaN       NaN          NaN       NaN  1.800000e+02       0.000000
# 50%         NaN       NaN          NaN       NaN  2.070000e+03      14.000000
# 75%         NaN       NaN          NaN       NaN  2.235675e+04     235.000000
# max         NaN       NaN          NaN       NaN  5.515465e+07  646281.000000
#
# ...

# %%
#e. Find which continent has maximum 'human_development_index'.
df['human_development_index'].max()
df.max(axis = 0)
# Out:
# /tmp/ipykernel_17395/894608167.py:3: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max(axis = 0)
# location                                  Zimbabwe
# date                                      31/12/19
# total_cases                             55154651.0
# new_cases                                 646281.0
# new_cases_smoothed                      584981.857
# total_deaths                             1328537.0
# new_deaths                                 10600.0
# new_deaths_smoothed                       9027.714
# total_cases_per_million                  76541.772
# new_cases_per_million                     8652.658
# new_cases_smoothed_per_million            2472.188
# total_deaths_per_million                  1248.014
# ...

# %%
#f. Find which continent has minimum 'gdp_per_capita'.
df["gdp_per_capita"].min()
df.min(axis = 0)
# Out:
# /tmp/ipykernel_17395/137923590.py:3: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min(axis = 0)
# location                              Afghanistan
# date                                     01/01/20
# total_cases                                   1.0
# new_cases                                 -8261.0
# new_cases_smoothed                         -552.0
# total_deaths                                  1.0
# new_deaths                                -1918.0
# new_deaths_smoothed                      -232.143
# total_cases_per_million                     0.001
# new_cases_per_million                   -2212.545
# new_cases_smoothed_per_million           -269.978
# total_deaths_per_million                      0.0
# ...

# %% [markdown]
# # 4. Filter the dataframe with only this columns
# ['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'] and update the data frame.

# %%
df=pd.read_csv("https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv",usecols=['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'])
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# # 5. Data Cleaning

# %%
#a. Remove all duplicates observations
df.drop_duplicates()
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
#b. Find missing values in all columns
df.isnull().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %%
#c. Remove all observations where continent column value is missing
#Tip : using subset parameter in dropna.
df.dropna(axis='columns')
# Out:
#             location      date
# 0        Afghanistan  31/12/19
# 1        Afghanistan  01/01/20
# 2        Afghanistan  02/01/20
# 3        Afghanistan  03/01/20
# 4        Afghanistan  04/01/20
# ...              ...       ...
# 57389  International  13/11/20
# 57390  International  14/11/20
# 57391  International  15/11/20
# 57392  International  16/11/20
# 57393  International  17/11/20
#
# [57394 rows x 2 columns]

# %%
#d. Fill all missing values with 0
df.fillna(0)
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          0.0           0.0
# 1          Asia    Afghanistan  01/01/20          0.0           0.0
# 2          Asia    Afghanistan  02/01/20          0.0           0.0
# 3          Asia    Afghanistan  03/01/20          0.0           0.0
# 4          Asia    Afghanistan  04/01/20          0.0           0.0
# ...         ...            ...       ...          ...           ...
# 57389         0  International  13/11/20        696.0           7.0
# 57390         0  International  14/11/20        696.0           7.0
# 57391         0  International  15/11/20        696.0           7.0
# 57392         0  International  16/11/20        696.0           7.0
# 57393         0  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# # 6. Date time format :

# %%
#a. Convert date column in datetime format using pandas.to_datetime
df["date"] = pd.to_datetime(df["date"])
df["date"]
# Out:
# 0       2019-12-31
# 1       2020-01-01
# 2       2020-02-01
# 3       2020-03-01
# 4       2020-04-01
#            ...
# 57389   2020-11-13
# 57390   2020-11-14
# 57391   2020-11-15
# 57392   2020-11-16
# 57393   2020-11-17
# Name: date, Length: 57394, dtype: datetime64[ns]

# %%
#b. Create new column month after extracting month data from datecolumn.
df['Month'] = df['date'].dt.month 
df['Month']
# Out:
# 0        12
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 57389    11
# 57390    11
# 57391    11
# 57392    11
# 57393    11
# Name: Month, Length: 57394, dtype: int64

# %% [markdown]
# # 7. Data Aggregation:

# %%
#a. Find max value in all columns using groupby function on 'continent' column
#Tip: use reset_index() after applying groupby
df_groupby=df.groupby('continent').max().reset_index(drop=True)
df_groupby
# Out:
#                        location       date  total_cases  total_deaths  \
# 0                      Zimbabwe 2020-12-11     752269.0       20314.0
# 1                         Yemen 2020-12-11    8874290.0      130519.0
# 2                       Vatican 2020-12-11    1991233.0       52147.0
# 3  United States Virgin Islands 2020-12-11   11205486.0      247220.0
# 4             Wallis and Futuna 2020-12-11      27750.0         907.0
# 5                     Venezuela 2020-12-11    5876464.0      166014.0
#
#    gdp_per_capita  human_development_index  Month
# 0       26382.287                    0.797     12
# 1      116935.600                    0.933     12
# 2       94277.965                    0.953     12
# 3       54225.446                    0.926     12
# 4       44648.710                    0.939     12
# 5       22767.037                    0.843     12

# %%
#b. Store the result in a new dataframe named 'df_groupby'.
#(Use df_groupby dataframe for all further analysis)
df_groupby=df_groupby.copy()
df_groupby
# Out:
#                        location       date  total_cases  total_deaths  \
# 0                      Zimbabwe 2020-12-11     752269.0       20314.0
# 1                         Yemen 2020-12-11    8874290.0      130519.0
# 2                       Vatican 2020-12-11    1991233.0       52147.0
# 3  United States Virgin Islands 2020-12-11   11205486.0      247220.0
# 4             Wallis and Futuna 2020-12-11      27750.0         907.0
# 5                     Venezuela 2020-12-11    5876464.0      166014.0
#
#    gdp_per_capita  human_development_index  Month
# 0       26382.287                    0.797     12
# 1      116935.600                    0.933     12
# 2       94277.965                    0.953     12
# 3       54225.446                    0.926     12
# 4       44648.710                    0.939     12
# 5       22767.037                    0.843     12

# %% [markdown]
# # 8. Feature Engineering :

# %%
#a. Create a new feature 'total_deaths_to_total_cases' by ratio of 'total_deaths' column to 'total_cases'
df_groupby["total_deaths_to_total_cases"]=df_groupby["total_deaths"]*100/df_groupby["total_cases"]
df_groupby
# Out:
#                        location       date  total_cases  total_deaths  \
# 0                      Zimbabwe 2020-12-11     752269.0       20314.0
# 1                         Yemen 2020-12-11    8874290.0      130519.0
# 2                       Vatican 2020-12-11    1991233.0       52147.0
# 3  United States Virgin Islands 2020-12-11   11205486.0      247220.0
# 4             Wallis and Futuna 2020-12-11      27750.0         907.0
# 5                     Venezuela 2020-12-11    5876464.0      166014.0
#
#    gdp_per_capita  human_development_index  Month  total_deaths_to_total_cases
# 0       26382.287                    0.797     12                     2.700364
# 1      116935.600                    0.933     12                     1.470754
# 2       94277.965                    0.953     12                     2.618830
# 3       54225.446                    0.926     12                     2.206241
# 4       44648.710                    0.939     12                     3.268468
# ...

# %% [markdown]
# # 9. Data Visualization :

# %%
#a.Perform Univariate analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(x=df_groupby["gdp_per_capita"])
# Out:
# <Axes: xlabel='gdp_per_capita', ylabel='Count'>

# %%
#b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
sns.scatterplot(x="total_cases",y='gdp_per_capita',data=df_groupby)
plt.show()

# %%
#c. Plot Pairplot on df_groupby dataset.
sns.pairplot(data=df_groupby)

# %%
#d. Plot a bar plot of 'continent' column with 'total_cases' .
#Tip : using kind='bar' in seaborn catplot
sns.catplot(data=df_groupby,x="location",y="total_cases",kind="bar")

# %% [markdown]
# # 10.Save the df_groupby dataframe in your local drive using pandas. to_csv function .

# %%
df_groupby
# Out:
#                        location       date  total_cases  total_deaths  \
# 0                      Zimbabwe 2020-12-11     752269.0       20314.0
# 1                         Yemen 2020-12-11    8874290.0      130519.0
# 2                       Vatican 2020-12-11    1991233.0       52147.0
# 3  United States Virgin Islands 2020-12-11   11205486.0      247220.0
# 4             Wallis and Futuna 2020-12-11      27750.0         907.0
# 5                     Venezuela 2020-12-11    5876464.0      166014.0
#
#    gdp_per_capita  human_development_index  Month  total_deaths_to_total_cases
# 0       26382.287                    0.797     12                     2.700364
# 1      116935.600                    0.933     12                     1.470754
# 2       94277.965                    0.953     12                     2.618830
# 3       54225.446                    0.926     12                     2.206241
# 4       44648.710                    0.939     12                     3.268468
# ...

# %%
df_groupby.to_csv("df_groupby.csv")
